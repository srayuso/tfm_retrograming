# %%
from ipysankeywidget import SankeyWidget

# %%
links = [
    {
      "source": "Feedback",
      "target": "new_releases",
      "type": "new_releases",
      "value": 3
    },
    {
      "source": "Feedback",
      "target": "dev",
      "type": "dev",
      "value": 687
    },
    {
      "source": "Feedback",
      "target": "praise",
      "type": "praise",
      "value": 180
    },
    {
      "source": "Feedback",
      "target": "germans",
      "type": "germans",
      "value": 142
    },
    {
      "source": "Feedback",
      "target": "vb_world",
      "type": "vb_world",
      "value": 40
    },
    {
      "source": "Feedback",
      "target": "marketplace",
      "type": "marketplace",
      "value": 78
    },
    {
      "source": "Feedback",
      "target": "hardware/fixes",
      "type": "hardware/fixes",
      "value": 61
    },
    {
      "source": "FlashBoy",
      "target": "hardware/fixes",
      "type": "hardware/fixes",
      "value": 108
    },
    {
      "source": "FlashBoy",
      "target": "dev",
      "type": "dev",
      "value": 64
    },
    {
      "source": "FlashBoy",
      "target": "praise",
      "type": "praise",
      "value": 1030
    },
    {
      "source": "FlashBoy",
      "target": "marketplace",
      "type": "marketplace",
      "value": 197
    },
    {
      "source": "FlashBoy",
      "target": "new_releases",
      "type": "new_releases",
      "value": 15
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "vb_world",
      "type": "vb_world",
      "value": 966
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "germans",
      "type": "germans",
      "value": 379
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "dev",
      "type": "dev",
      "value": 1627
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "misc",
      "type": "misc",
      "value": 8
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "hardware/fixes",
      "type": "hardware/fixes",
      "value": 3461
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "praise",
      "type": "praise",
      "value": 5920
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "writings",
      "type": "writings",
      "value": 419
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "new_releases",
      "type": "new_releases",
      "value": 916
    },
    {
      "source": "Main Virtual Boy Discussion",
      "target": "marketplace",
      "type": "marketplace",
      "value": 6856
    },
    {
      "source": "Marketplace",
      "target": "misc",
      "type": "misc",
      "value": 5
    },
    {
      "source": "Marketplace",
      "target": "writings",
      "type": "writings",
      "value": 4
    },
    {
      "source": "Marketplace",
      "target": "praise",
      "type": "praise",
      "value": 408
    },
    {
      "source": "Marketplace",
      "target": "marketplace",
      "type": "marketplace",
      "value": 1686
    },
    {
      "source": "Marketplace",
      "target": "dev",
      "type": "dev",
      "value": 15
    },
    {
      "source": "Marketplace",
      "target": "vb_world",
      "type": "vb_world",
      "value": 4
    },
    {
      "source": "Marketplace",
      "target": "new_releases",
      "type": "new_releases",
      "value": 5
    },
    {
      "source": "Marketplace",
      "target": "germans",
      "type": "germans",
      "value": 36
    },
    {
      "source": "Marketplace",
      "target": "hardware/fixes",
      "type": "hardware/fixes",
      "value": 110
    },
    {
      "source": "Offtopic",
      "target": "germans",
      "type": "germans",
      "value": 38
    },
    {
      "source": "Offtopic",
      "target": "marketplace",
      "type": "marketplace",
      "value": 577
    },
    {
      "source": "Offtopic",
      "target": "hardware/fixes",
      "type": "hardware/fixes",
      "value": 281
    },
    {
      "source": "Offtopic",
      "target": "writings",
      "type": "writings",
      "value": 4
    },
    {
      "source": "Offtopic",
      "target": "new_releases",
      "type": "new_releases",
      "value": 76
    },
    {
      "source": "Offtopic",
      "target": "vb_world",
      "type": "vb_world",
      "value": 838
    },
    {
      "source": "Offtopic",
      "target": "dev",
      "type": "dev",
      "value": 208
    },
    {
      "source": "Offtopic",
      "target": "praise",
      "type": "praise",
      "value": 1333
    },
    {
      "source": "Offtopic",
      "target": "misc",
      "type": "misc",
      "value": 2
    },
    {
      "source": "PVB Coding Competition 2008",
      "target": "dev",
      "type": "dev",
      "value": 234
    },
    {
      "source": "PVB Coding Competition 2008",
      "target": "praise",
      "type": "praise",
      "value": 5
    },
    {
      "source": "PVB Coding Competition 2008",
      "target": "marketplace",
      "type": "marketplace",
      "value": 6
    },
    {
      "source": "PVB Coding Competition 2010",
      "target": "dev",
      "type": "dev",
      "value": 277
    },
    {
      "source": "PVB Coding Competition 2010",
      "target": "praise",
      "type": "praise",
      "value": 16
    },
    {
      "source": "PVB Coding Competition 2013",
      "target": "dev",
      "type": "dev",
      "value": 313
    },
    {
      "source": "PVB Coding Competition 2013",
      "target": "praise",
      "type": "praise",
      "value": 110
    },
    {
      "source": "VB Dev Repository",
      "target": "dev",
      "type": "dev",
      "value": 30
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "marketplace",
      "type": "marketplace",
      "value": 29
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "new_releases",
      "type": "new_releases",
      "value": 83
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "dev",
      "type": "dev",
      "value": 5045
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "germans",
      "type": "germans",
      "value": 40
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "vb_world",
      "type": "vb_world",
      "value": 55
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "hardware/fixes",
      "type": "hardware/fixes",
      "value": 435
    },
    {
      "source": "Virtual Boy Development Board",
      "target": "praise",
      "type": "praise",
      "value": 1319
    }
  ]


rank_sets = [
    { 'type': 'same', 'nodes': ['C', 'D'] }
]

order = [
    ['Main Virtual Boy Discussion',
    'Virtual Boy Development Board',
    'Offtopic',
    'Marketplace',
    'FlashBoy',
    'Feedback',
    'PVB Coding Competition 2008',
    'PVB Coding Competition 2010',
    'PVB Coding Competition 2013',
    'VB Dev Repository'],
    ['marketplace',
    'praise',
    'dev',
    'hardware/fixes',
    'vb_world',
    'new_releases',
    'germans',
    'writings',
    'misc']
]

# %%
sankey = SankeyWidget(links=links, order=order, margins=dict(top=0, bottom=0, left=210, right=95))
sankey
# Out:
# SankeyWidget(links=[{'source': 'Feedback', 'target': 'new_releases', 'type': 'new_releases', 'value': 3}, {'so…
